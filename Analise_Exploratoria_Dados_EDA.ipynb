# %% [markdown]
# ## Ideia central
# <br>
# A ideia dessa Análise Exploratória de Dados é avaliar a possibilidade de abrir um curso preparatório de ENEM para alunos com mais de 40 anos.
#
# ### Descrição do Problema
# <br>
# A maioria dos cursos preparatórios são voltados para um público jovem em uma faixa de idade entre 17 e 20 anos que recém concluiram seus estudos do ensino médio.
# Tendo em vista esse nicho comercial, o cliente  - uma rede de ensino - solicitou uma analise do perfil dos candidatos de ENEM que possuem mais de 40 anos para verificar a viabilidade de um curso exclusivo para essa faixa etária.
#
# ### Resolução do problema
# <br>
# Para ajudar o cliente a decidir se é viável a abertura de um curso preparatório exclusivo para candidados acima de 40 anos foi realizada a análise de perfil dos canditatos do enem de 2021 dessa faixa etária.
# <br>
# Entre as analises realizadas estão:<br>
#  -  Perfil sócio-economico dos canditados<br>
#  -  Descrição da porcentagem de cantidatos por estado<br>
#  -  Acesso dos candidatos a computador e internet<br>
#  -  Analise das notas dos candidatos por área de conhecimento
#
#
# ##### OBS
# Essa é uma problemática fictícia criada pela autora

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import ListedColormap
import seaborn as sns
# %matplotlib inline

primary = ['#FFAAAA','#D46A6A', '#AA3939', '#801515', '#550000']
secondary_1 = ['#FFD1AA','#D49A6A', '#AA6C39', '#804515', '#552600']
secondary_2 = ['#669999','#407F7F', '#226666', '#0D4D4D', '#003333']
complement = ['#88CC88','#55AA55', '#2D882D', '#116611', '#004400']
claro = ['#FFAAAA', '#FFD1AA', '#669999', '#88CC88' ]
ps1 = ['#804515','#801515', '#552600']

print(sns.palplot(sns.color_palette(ps1)))
my_colors = ListedColormap(sns.color_palette())
# Out:
# None

# %%
sns.set_palette(ps1)
sns.set_context("paper")

# %%
dados = pd.read_csv('Dados_Gerais_Enem_2021.csv')

# %%
idade = dados['TP_FAIXA_ETARIA']
idade = pd.DataFrame(idade)

# %%
print(idade.describe())
# Out:
#        TP_FAIXA_ETARIA
# count     3.389832e+06
# mean      5.306013e+00
# std       3.902871e+00
# min       1.000000e+00
# 25%       2.000000e+00
# 50%       4.000000e+00
# 75%       7.000000e+00
# max       2.000000e+01

# %%
plt.figure(figsize=(12,7))
plt.title('Distribuição de frequencia das faixas etarias', pad=20, fontsize=18)
ax = sns.histplot(data = dados, x='TP_FAIXA_ETARIA', hue='TP_SEXO', bins=20)
ax.legend(['Feminino','Masculino'])
#ax.legend(['Não declarado','Branca','Preta','Parda','Amarela','Indígena'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Idade', fontsize=14)
# Out:
# Text(0.5, 0, 'Idade')

# %%
mais_de_40_anos = idade >13
mais_de_40_anos.sum()
# Out:
# TP_FAIXA_ETARIA    131934
# dtype: int64

# %%
mais_de_40_anos.sum()/3.389832e+06
# Out:
# TP_FAIXA_ETARIA    0.038921
# dtype: float64

# %% [markdown]
# - 75% dos participantes tem até 22 anos
# - apenas 3,9% dos participantes tem acima de 40 anos

# %% [markdown]
# ### Perfil dos participantes 40+

# %%
participantes_40 = dados.loc[dados['TP_FAIXA_ETARIA']>13]

# %%
plt.figure(figsize=(12,7))
plt.title('Distribuição de frênquência das notas', pad=20, fontsize=18)
ax = sns.histplot(data = participantes_40, x='NU_NOTA_REDACAO', palette=ps1, hue='TP_SEXO', bins=50)
ax.legend(['Feminino','Masculino'])
#ax.legend(['Não declarado','Branca','Preta','Parda','Amarela','Indígena'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Nota Redação', fontsize=14)
ax = ax
# Out:
# C:\Users\nike_\AppData\Local\Temp\ipykernel_13744\3941060188.py:3: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   ax = sns.histplot(data = participantes_40, x='NU_NOTA_REDACAO', palette=ps1, hue='TP_SEXO', bins=50)

# %% [markdown]
# #### Conclusão do ensino médio

# %%
plt.figure(figsize=(12,7))
plt.title('Situação de Conclusão do Ensino Médio', pad=20, fontsize=18)
ax = sns.countplot(data = participantes_40, x= 'TP_ST_CONCLUSAO', hue = 'TP_SEXO', palette = ps1)
ax.legend(['Feminino','Masculino'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Situação', fontsize=14)
# Out:
# Text(0.5, 0, 'Situação')

# %%
plt.figure(figsize=(12,7))
plt.title('Ano de Conclusão do Ensino Médio', pad=20, fontsize=18)
ax = sns.countplot(data = participantes_40, x= 'TP_ANO_CONCLUIU', hue = 'TP_SEXO', palette = ps1)
ax.legend(['Feminino','Masculino'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Situação', fontsize=14)
# Out:
# Text(0.5, 0, 'Situação')

# %%
plt.figure(figsize=(12,7))
plt.title('Treineiros', pad=20, fontsize=18)
ax = sns.countplot(data = participantes_40, x= 'IN_TREINEIRO', hue = 'TP_SEXO', palette = ps1)
ax.legend(['Feminino','Masculino'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Situação', fontsize=14)
# Out:
# Text(0.5, 0, 'Situação')

# %% [markdown]
# #### Classe Social

# %%
plt.figure(figsize=(12,7))
plt.title('Renda', pad=20, fontsize=18)
ax = sns.countplot(data = participantes_40, x= 'Q006', hue = 'TP_SEXO', palette = ps1)
ax.legend(['Feminino','Masculino'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Situação', fontsize=14)
# Out:
# Text(0.5, 0, 'Situação')

# %% [markdown]
# #### Estado Civíl

# %%
plt.figure(figsize=(12,7))
plt.title('Treineiros', pad=20, fontsize=18)
ax = sns.countplot(data = participantes_40, x= 'TP_ESTADO_CIVIL', hue = 'TP_SEXO', palette = ps1)
ax.legend(['Feminino','Masculino'])
ax.set_ylabel('Candidatos', fontsize=14)
ax.set_xlabel('Situação', fontsize=14)
# Out:
# Text(0.5, 0, 'Situação')

# %% [markdown]
# #### Índice de Comparecimento

# %%
f, axs = plt.subplots(2, 2, figsize=(12, 7))
sns.countplot(data=participantes_40, x='TP_PRESENCA_CN', hue="TP_SEXO", ax=axs[0,0])
sns.countplot(data=participantes_40, x='TP_PRESENCA_CH', hue="TP_SEXO", ax=axs[0,1])
sns.countplot(data=participantes_40, x='TP_PRESENCA_LC', hue="TP_SEXO", ax=axs[1,0])
sns.countplot(data=participantes_40, x='TP_PRESENCA_MT', hue="TP_SEXO", ax=axs[1,1])
f.tight_layout()

# %% [markdown]
# #### Notas

# %%
#Novo dataset para as notas, assim é possivel remover os valores nulos sem interferir em outros resultados
notas = participantes_40[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC','TP_SEXO', 'NU_NOTA_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_REDACAO']]
notas.shape
# Out:
# (131934, 7)

# %%
notas.dropna(inplace=True)
notas.shape
# Out:
# C:\Users\nike_\AppData\Local\Temp\ipykernel_13744\1104233361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notas.dropna(inplace=True)
# (64054, 7)

# %%
notas.isnull().sum()
# Out:
# NU_NOTA_CN           0
# NU_NOTA_CH           0
# NU_NOTA_LC           0
# TP_SEXO              0
# NU_NOTA_MT           0
# TP_STATUS_REDACAO    0
# NU_NOTA_REDACAO      0
# dtype: int64

# %%
data = pd.melt(notas, value_vars=['NU_NOTA_REDACAO', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT' ], id_vars='TP_SEXO')

# %%
plt.figure(figsize=(12,7))
plt.title('Notas por Prova 40 +', pad=20, fontsize=18)
sns.violinplot(x='variable', y='value', hue='TP_SEXO', split= True, data=data)
# Out:
# <AxesSubplot: title={'center': 'Notas por Prova 40 +'}, xlabel='variable', ylabel='value'>

# %%
participantes_menos_40 = dados.loc[dados['TP_FAIXA_ETARIA']<14]

notas_menos_40 = participantes_menos_40[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC','TP_SEXO', 'NU_NOTA_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_REDACAO']]

notas_menos_40.dropna(inplace= True)

notas_menos_40.isnull().sum()
# Out:
# C:\Users\nike_\AppData\Local\Temp\ipykernel_13744\611919318.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notas_menos_40.dropna(inplace= True)
# NU_NOTA_CN           0
# NU_NOTA_CH           0
# NU_NOTA_LC           0
# TP_SEXO              0
# NU_NOTA_MT           0
# TP_STATUS_REDACAO    0
# NU_NOTA_REDACAO      0
# dtype: int64

# %%
data_menos_40 = pd.melt(notas_menos_40, value_vars=['NU_NOTA_REDACAO', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT' ], id_vars='TP_SEXO')

# %%
plt.figure(figsize=(12,7))
plt.title('Notas por Prova 40 -', pad=20, fontsize=18)
sns.violinplot(x='variable', y='value', hue='TP_SEXO', split= True, data=data_menos_40)
# Out:
# <AxesSubplot: title={'center': 'Notas por Prova 40 -'}, xlabel='variable', ylabel='value'>

# %% [markdown]
# #### Participantes por estado

# %%
import geopandas as gpd 
import geobr

# %%
geobr.list_geobr()
# Out:
# Function: read_country
# Geographies available: Country
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_region
# Geographies available: Region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_state
# Geographies available: States
# Years available: 1872, 1900, 1911, 1920, 1933, 1940, 1950, 1960, 1970, 1980, 1991, 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_meso_region
# Geographies available: Meso region
# Years available: 2000, 2001, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
# Source: IBGE
# ------------------------------
# Function: read_micro_region
# Geographies available: Micro region
# ...

# %%
Brasil = geobr.read_country(year = 2020)

# %%
# criando o grupo de estados
dados_localizacao_participantes_40 = participantes_40.groupby('SG_UF_PROVA').count().sort_values('SG_UF_PROVA', ascending=False)

# %%
# criando o grupo de canditados totais por estado
dados_localizacao_participantes_totais = dados.groupby('SG_UF_PROVA').count().sort_values('SG_UF_PROVA', ascending=False)

# %%
# normalização dos dados

candidatos_40_normalizados = (dados_localizacao_participantes_40/dados_localizacao_participantes_totais) *100

# %%
candidatos_40_normalizados = candidatos_40_normalizados['TP_FAIXA_ETARIA']

# %%
# Informações para o mapa
Brasil['NAME_1'] = candidatos_40_normalizados.index
Brasil['NOTA_ENEM_NORMALIZADA'] = candidatos_40_normalizados.values

ax = Brasil.plot(figsize=(14,6),
                 column='NOTA_ENEM_NORMALIZADA',
                 cmap=plt.cm.get_cmap('YlOrBr'),
                 legend=True).set_axis_off()
# Out:
# C:\Users\nike_\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\geopandas\plotting.py:33: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# C:\Users\nike_\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %% [markdown]
# ### Acesso a computador e internet

# %%
f, axs = plt.subplots(2, 2, figsize=(12, 7))
sns.countplot(data=participantes_40, x='Q024', hue="TP_SEXO", ax=axs[0,0])
sns.countplot(data=participantes_40, x='Q025', hue="TP_SEXO", ax=axs[0,1])
f.tight_layout()
